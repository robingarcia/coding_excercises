# %% [markdown]
# <a href="https://colab.research.google.com/github/robingarcia/coding_excercises/blob/master/lab_day1/day1_code00_basic_python_%5BEXERCISE%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Trying out Jupyter Notebooks with basic relevant Python
#
# Let's get acquainted with Python (3) and **interactive Jupyter Notebooks** (ipynb), our main working tools throughout the course.
#
# First of all, in an `ipynb` file we distinguish:
#
# - text chunks: where we write instructions, comments, explanations (like this one!)
# - code chunks: where we write Python instructions to be executed
#
# As for `Python`, we will mainly use three fundamental libraries:
#
# 1. `numpy`: to work with arrays (vectors, matrices)
# 2. `pandas`: to work with dataframes (reading and manipulating datasets)
# 3. `matplotlib`: to visualize data and results (making plots)
#
# In addition, we'll use `Keras` for deep learning: we'll see more on this later.
#
# This is not a course on Python, not even an introduction: just a few notes to get some basic acquaintance with these libraries.

# %%
my_var = 3

# %%
print(my_var)
# Out:
# 3

# %% [markdown]
# # How to proceed?
# Tell us your preference!

# %% [markdown]
# ### Numpy
#
# We start by importing the library and creating a vector (one-dimensional array)

# %%
## import libraries
import numpy as np

arr_1d = np.array([1, 2, 3, 4, 5, 0, 7, 1, 9])
print(arr_1d)
# Out:
# [1 2 3 4 5 0 7 1 9]

# %% [markdown]
# We can use the array attribute `shape` to get the dimensions of the array

# %%
arr_1d.shape
# Out:
# (9,)

# %% [markdown]
# We see that by default `numpy` does not specify the second dimension for one-dimensional arrays (vectors). If you want to make this explicit (which may turn out to be helpful for some array operations and to avoid ambiguous results), you can use the **function** `reshape()`:

# %%
arr_1d = arr_1d.reshape(len(arr_1d),1)
print(arr_1d.shape)
# Out:
# (9, 1)

# %% [markdown]
# We can also build arrays with more dimensions (matrices, "tensors"): in deep learning, mastering the dimensions of tensors (multidimensional arrays) is very important!

# %%
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])
print(arr_2d)
print(arr_2d.shape) ## 2 rows, 3 columns
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)

# %%
arr_3d = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])
print(arr_3d)
print(arr_3d.shape) ## 2 channels/bands/layers, 2 row, 3 columns
# Out:
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]]
# (2, 2, 3)

# %%
value = arr_3d[0,1,2] ## get first layer, second row, third element (indexing in Python starts at 0!)
print(value)

# %% [markdown]
# - use array indices for slicing: `[start:end]`
# - a step argument can be added: `[start:end:step]`

# %%
print(arr_1d[:]) ## entire array
print(arr_1d[3:6]) ## elements 4, 5 and 6 of the array
print(arr_1d[:3]) ## first three elements of the array --> equivalent to arr_1d[0:3]
print(arr_1d[7:]) ## last two elements of the array --> equivalent to arr_1d[7:len(arr_1d)]
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]
#  [0]
#  [7]
#  [1]
#  [9]]
# [[4]
#  [5]
#  [0]]
# [[1]
#  [2]
#  [3]]
# [[1]
#  [9]]

# %% [markdown]
# More on `numpy` can be found for instance <a href='https://numpy.org/devdocs/user/quickstart.html'>here</a>
#
# ### Pandas
#
# Python library to work with tabular data (multidimensional), in the form of mainly **dataframes**.
#
# We load the library and create a first dataframe:

# %%
import pandas as pd

df = pd.DataFrame(np.random.randn(8, 4), columns=list('ABCD')) ## list() constructor converts string to a list of characters
df
# Out:
#           A         B         C         D
# 0 -2.343804 -0.012583  2.055216  1.426685
# 1 -1.867979  0.768356  0.420604 -0.714971
# 2  0.264848 -1.279382 -1.006291 -0.302753
# 3 -0.772933 -0.668536 -0.476801 -0.117917
# 4 -0.372353 -0.737683  0.175816 -0.726339
# 5 -0.602636  0.723521  0.348974  1.506158
# 6 -0.513913 -0.493176 -0.159405  0.896615
# 7 -0.299063 -0.091836  0.900985 -1.217763

# %% [markdown]
# With the dataframe attribute `dtypes` we can get the data type of each column in a Pandas dataframe:

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %% [markdown]
# The Pandas function `head()` will show the first few rows of the dataframe; the attribute `columns` returns the column names.

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -2.343804 -0.012583  2.055216  1.426685
# 1 -1.867979  0.768356  0.420604 -0.714971
# 2  0.264848 -1.279382 -1.006291 -0.302753
# 3 -0.772933 -0.668536 -0.476801 -0.117917
# 4 -0.372353 -0.737683  0.175816 -0.726339

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# With the function `to_numpy()` we convert a dataframe to an array; then we can slice it as we already saw for numpy arrays

# %%
arr = df.to_numpy()
arr
# Out:
# array([[-2.34380447, -0.01258317,  2.05521635,  1.4266848 ],
#        [-1.86797928,  0.76835581,  0.42060441, -0.71497149],
#        [ 0.26484811, -1.27938194, -1.0062914 , -0.3027526 ],
#        [-0.77293299, -0.66853603, -0.4768012 , -0.11791654],
#        [-0.37235316, -0.73768263,  0.17581551, -0.72633859],
#        [-0.60263566,  0.72352051,  0.34897397,  1.50615847],
#        [-0.51391254, -0.49317579, -0.15940498,  0.89661483],
#        [-0.29906313, -0.0918356 ,  0.90098511, -1.21776256]])

# %%
arr[:,1] ## get second column
# Out:
# array([-0.01258317,  0.76835581, -1.27938194, -0.66853603, -0.73768263,
#         0.72352051, -0.49317579, -0.0918356 ])

# %% [markdown]
# You can also slice directly the Pandas dataframe:
#
# 1. by column name

# %%
df['A']
# Out:
# 0   -2.343804
# 1   -1.867979
# 2    0.264848
# 3   -0.772933
# 4   -0.372353
# 5   -0.602636
# 6   -0.513913
# 7   -0.299063
# Name: A, dtype: float64

# %% [markdown]
# 2. by slicing by rows

# %%
df[0:2]
# Out:
#           A         B         C         D
# 0 -2.343804 -0.012583  2.055216  1.426685
# 1 -1.867979  0.768356  0.420604 -0.714971

# %% [markdown]
# 3. by row and/or column names using the `.loc` syntax

# %%
print(df.loc[df.index.values[0]])
df.loc[:, ['B','C']]
# Out:
# A   -2.343804
# B   -0.012583
# C    2.055216
# D    1.426685
# Name: 0, dtype: float64
#           B         C
# 0 -0.012583  2.055216
# 1  0.768356  0.420604
# 2 -1.279382 -1.006291
# 3 -0.668536 -0.476801
# 4 -0.737683  0.175816
# 5  0.723521  0.348974
# 6 -0.493176 -0.159405
# 7 -0.091836  0.900985

# %% [markdown]
# 4. by position using the `.iloc` syntax

# %%
df.iloc[0:2,2:4]
# Out:
#           C         D
# 0  2.055216  1.426685
# 1  0.420604 -0.714971

# %% [markdown]
# More on `pandas` <a href='https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html'>here</a>
#
# ### Matplotlib
#
# `matplotlib` is a versatile Python library for data visualization which allows you to produce a very large variety of high-quality plots.
# We import the module `pyplot` from the library and produce a first basic plot:

# %%
from matplotlib import pyplot as plt

x = np.array([1, 2, 3, 4])
y = np.array([1, 4, 9, 16])
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y)

ax = plt.gca()
ax.set_xlim([0, 10])
ax.set_ylim([0, 20])

plt.show() ## not strictly necessary in interactive mode (as ipython or jupyter notebooks)

# %% [markdown]
# Instead of a diagram (line plot), we can also make a **scatter plot**:

# %%
x = np.array([1, 2, 3, 4, 0, 2, 7, 4, 10])
y = np.array([1, 4, 9, 16, 1, 3, 9, 8, 15])
plt.scatter(x,y)

# %% [markdown]
# For categorical data, a **barplot** can be used:

# %%
names = ['A', 'B', 'c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.plot(131)
plt.bar(names, values)
plt.show()

# %% [markdown]
# We can plot a distribution from synthetic data using a **histogram**:

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# You can also plot directly from a Pandas dataframe:

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=list('ABCD'))
df
# Out:
#             A         B         C         D
# 0   -0.551033 -0.153125  1.541624  0.577037
# 1    0.531933 -1.047054  1.843541  0.299975
# 2    1.664764  0.193479  0.129391  0.401195
# 3    0.869317  0.485031  0.667927 -2.028949
# 4   -0.772092  1.435103  2.329923  0.200041
# ..        ...       ...       ...       ...
# 995 -0.549635 -0.770845 -1.756057  1.196229
# 996  0.094278 -0.576355 -2.554584 -0.136101
# 997 -1.122349  0.398234  0.588374  0.592826
# 998 -0.882750 -0.291917 -1.402986  0.358141
# 999  0.433770  2.678805  1.743479  1.650499
#
# [1000 rows x 4 columns]

# %%
plt.plot(df)
plt.show()

# %%
df = df.cumsum() ## cumulative sums per columns
df
# Out:
#           a         b         c         d
# 0  0.862371  0.938207  0.673418  0.376836
# 1  0.930329  1.780593  1.324879  1.136818
# 2  1.105884  2.042746  1.742919  1.927292
# 3  1.900191  2.900838  1.800145  2.833754
# 4  2.043143  3.073611  2.725236  3.193744
# 5  2.629868  3.330833  3.418026  3.232026
# 6  3.140541  4.192298  3.700407  3.381026
# 7  3.943842  4.225467  4.537523  3.995975
# 8  4.721605  4.461561  4.623363  4.329169
# 9  4.900601  5.158466  4.733467  5.217391

# %%
plt.figure()
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# In Pandas, plot functions can be called directly on dataframes, e.g. using the function `plot.bar()` (we saw an example earlier with `df.plot()`)

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.bar();

# %% [markdown]
# More on `matplotlib` <a href='https://matplotlib.org/tutorials/introductory/pyplot.html'>here</a>
#
# ## Exercise 0.1: do-it-yourself!
#
# Now it is your turn to put together what you just learnt:
#
# 1. get your data
#   - create a numpy array (e.g. `np.random.randn()`); or
#   - create a pandas dataframe (e.g. `pd.DataFrame()`); or
#   - import a built-in dataset
#     - e.g. `from sklearn import datasets`
#     - `datasets.load_wine().data` (the data)
#     - `datasets.load_wine().feature_names` (the column names)
#     - (more on `sklearn` [here](https://scikit-learn.org/stable/))
#   - or a combination of these

# %%
#################
## your code here
#################

## 1. sample, generate or import your data
import numpy as np
my_array = np.random.randn()
print(my_array)
# Out:
# 1.995016318355493

# %%
## 2. convert to a pandas dataframe (e.g. pd.DataFrame())
import pandas as pd
covid_frame = pd.DataFrame()

# %%
## 3. give names to dataframe columns (e.g. df.columns = list_of_names)

# %%
## 4. subset the dataframe keeping only the columns that you wish to use

# %%
## 5. make sure that the columns you selected are of the correct data type for plotting

# %% [markdown]
# 2. plot the data

# %%
#################
## your code here
#################
